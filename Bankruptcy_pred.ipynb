# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('/content/Bankruptcy.csv')
data.shape # 6819 observations with 96 columns
# Out:
# (6819, 96)

# %%
len(data.columns)# 95 predictor variables and a target variable
# Out:
# 96

# %%
# Descriptive stats
data.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# 50%                                   0.559802
# 75%                                   0.589157
# max                                   1.000000
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        6819.000000
# mean                                            0.553589
# std                                             0.061595
# min                                             0.000000
# 25%                                             0.527277
# 50%                                             0.552278
# 75%                                             0.584105
# max                                             1.000000
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              6819.000000                   6819.000000
# mean                  0.607948                      0.607929
# std                   0.016934                      0.016916
# min                   0.000000                      0.000000
# 25%                   0.600445                      0.600434
# 50%                   0.605997                      0.605976
# 75%                   0.613914                      0.613842
# max                   1.000000                      1.000000
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             6819.000000                 6819.000000
# mean                 0.998755                    0.797190
# std                  0.013010                    0.012869
# min                  0.000000                    0.000000
# 25%                  0.998969                    0.797386
# 50%                  0.999022                    0.797464
# 75%                  0.999095                    0.797579
# max                  1.000000                    1.000000
#
#         After-tax net Interest Rate  \
# count                   6819.000000
# mean                       0.809084
# std                        0.013601
# min                        0.000000
# 25%                        0.809312
# 50%                        0.809375
# 75%                        0.809469
# max                        1.000000
#
#         Non-industry income and expenditure/revenue  ...  \
# count                                   6819.000000  ...
# mean                                       0.303623  ...
# std                                        0.011163  ...
# min                                        0.000000  ...
# 25%                                        0.303466  ...
# 50%                                        0.303525  ...
# 75%                                        0.303585  ...
# max                                        1.000000  ...
#
#         Net Income to Total Assets   Total assets to GNP price  \
# count                  6819.000000                6.819000e+03
# mean                      0.807760                1.862942e+07
# std                       0.040332                3.764501e+08
# min                       0.000000                0.000000e+00
# 25%                       0.796750                9.036205e-04
# 50%                       0.810619                2.085213e-03
# 75%                       0.826455                5.269777e-03
# max                       1.000000                9.820000e+09
#
#         No-credit Interval   Gross Profit to Sales  \
# count          6819.000000             6819.000000
# mean              0.623915                0.607946
# std               0.012290                0.016934
# min               0.000000                0.000000
# 25%               0.623636                0.600443
# 50%               0.623879                0.605998
# 75%               0.624168                0.613913
# max               1.000000                1.000000
#
#         Net Income to Stockholder's Equity   Liability to Equity  \
# count                          6819.000000           6819.000000
# mean                              0.840402              0.280365
# std                               0.014523              0.014463
# min                               0.000000              0.000000
# 25%                               0.840115              0.276944
# 50%                               0.841179              0.278778
# 75%                               0.842357              0.281449
# max                               1.000000              1.000000
#
#         Degree of Financial Leverage (DFL)  \
# count                          6819.000000
# mean                              0.027541
# std                               0.015668
# min                               0.000000
# 25%                               0.026791
# 50%                               0.026808
# 75%                               0.026913
# max                               1.000000
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        6819.000000              6819.0
# mean                                            0.565358                 1.0
# std                                             0.013214                 0.0
# min                                             0.000000                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565252                 1.0
# 75%                                             0.565725                 1.0
# max                                             1.000000                 1.0
#
#         Equity to Liability
# count           6819.000000
# mean               0.047578
# std                0.050014
# min                0.000000
# 25%                0.024477
# 50%                0.033798
# 75%                0.052838
# max                1.000000
#
# [8 rows x 96 columns]

# %%
data.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
#
819 non-null   float64
# dtypes: float64(93), int64(3)
# memory usage: 5.0 MB

# %%
data_corr = data.corr()
sb.heatmap(data_corr)  #heatmap for checking correlation between columns
plt.show()

# %%
threshold = 0.9 # To remove the columns that have the correlation >= 0.9
columns = np.full((data_corr.shape[0],), True, dtype=bool)
for i in range(data_corr.shape[0]):
    for j in range(i+1, data_corr.shape[0]):
        if data_corr.iloc[i,j] >= threshold:
            if columns[j]:
                columns[j] = False
selected_columns = data.columns[columns]
selected_columns
Data = data[selected_columns]

# %%
Data.shape # 18 columns are removed.
# Out:
# (6819, 78)

# %%
sb.heatmap(Data.corr())
plt.show()

# %%
x = Data.iloc[:,1:].values
y = Data.iloc[:,0].values
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25,random_state = 0)

#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
classifier1 = LogisticRegression(max_iter = 300, random_state = 0)
classifier1.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=300, random_state=0)

# %%
# Making the Confusion Matrix for training and testing sets

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Training data predictions and confusion matrix
y_pred_train = classifier1.predict(X_train)
cm_train = confusion_matrix(y_train, y_pred_train)
print('Confusion matrix on training data:\n', cm_train)
accuracy_train = classifier1.score(X_train, y_train)
print("Accuracy from logistic regression on training data:\n", accuracy_train)

# Plot confusion matrix for training data
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train, display_labels=classifier1.classes_)
disp_train.plot()
plt.title("Confusion Matrix - Training Data")
plt.show()

# Testing data predictions and confusion matrix
y_pred_test = classifier1.predict(X_test)
cm_test = confusion_matrix(y_test, y_pred_test)
print('Confusion matrix on testing data:\n', cm_test)
accuracy_test = classifier1.score(X_test, y_test)
print("Accuracy from logistic regression on testing data:\n", accuracy_test)

# Plot confusion matrix for testing data
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=classifier1.classes_)
disp_test.plot()
plt.title("Confusion Matrix - Testing Data")
plt.show()
# Out:
# Confusion matrix on training data:
#  [[4924   22]
#  [ 125   43]]
# Accuracy from logistic regression on training data:
#  0.9712553773953853
# Confusion matrix on testing data:
#  [[1639   14]
#  [  43    9]]
# Accuracy from logistic regression on testing data:
#  0.9665689149560117

# %% [markdown]
#  KNN Classification

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create the KNN classifier with Euclidean distance
classifier2 = KNeighborsClassifier(n_neighbors=80, metric='minkowski', p=2)
#Euclidean matrix is used
classifier2.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=80)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
# Making the Confusion Matrix for training and testing sets

y_pred = classifier2.predict(X_train)
cm = confusion_matrix(y_train, y_pred)
print('confusion matrix on training data:\n',cm)
accuracy = classifier2.score(X_train, y_train)
print("Accuracy from KNN classifier on training data \n", accuracy)


y_pred = classifier2.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print('confusion matrix on testing data:\n',cm)
accuracy = classifier2.score(X_test, y_test)
print("accuracy from KNN classifier on testing data\n", accuracy)
# Out:
# confusion matrix on training data:
#  [[4946    0]
#  [ 168    0]]
# Accuracy from KNN classifier on training data
#  0.9671490027375831
# confusion matrix on testing data:
#  [[1653    0]
#  [  52    0]]
# accuracy from KNN classifier on testing data
#  0.9695014662756598

# %% [markdown]
# Decision Tree Classifier

# %% [markdown]
# 1)Minimum samples per leaf node is 500

# %%
from sklearn import tree
classifier3 = tree.DecisionTreeClassifier(criterion = 'entropy', min_samples_split=500)
classifier3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=500)

# %%
# Making the Confusion Matrix for training and testing sets

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = classifier3.predict(X_train)
cm = confusion_matrix(y_train, y_pred)
print('confusion matrix on training data:\n',cm)
accuracy = classifier3.score(X_train, y_train)
print("Accuracy from Decision tree classifier on training data \n", accuracy)

y_pred = classifier3.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print('confusion matrix on testing data:\n',cm)
accuracy = classifier3.score(X_test, y_test)
print("accuracy from  classifier on testing data\n", accuracy)
# Out:
# confusion matrix on training data:
#  [[4946    0]
#  [ 168    0]]
# Accuracy from Decision tree classifier on training data
#  0.9671490027375831
# confusion matrix on testing data:
#  [[1653    0]
#  [  52    0]]
# accuracy from  classifier on testing data
#  0.9695014662756598

# %% [markdown]
# 2)Minimum samples per leaf node is 250.

# %%
classifier4 = tree.DecisionTreeClassifier(criterion = 'entropy', min_samples_split=250)
classifier4.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=250)

# %%
# Making the Confusion Matrix for training and testing sets

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = classifier4.predict(X_train)
cm = confusion_matrix(y_train, y_pred)
print('confusion matrix on training data:\n',cm)
accuracy = classifier4.score(X_train, y_train)
print("Accuracy from Decision tree classifier on training data \n", accuracy)


y_pred = classifier4.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print('confusion matrix on testing data:\n',cm)
accuracy = classifier4.score(X_test, y_test)
print("accuracy from Decision tree classifier on testing data\n", accuracy)
# Out:
# confusion matrix on training data:
#  [[4946    0]
#  [ 167    1]]
# Accuracy from Decision tree classifier on training data
#  0.9673445443879546
# confusion matrix on testing data:
#  [[1653    0]
#  [  52    0]]
# accuracy from Decision tree classifier on testing data
#  0.9695014662756598

# %% [markdown]
# 3) Minimum samples per leaf node is 375.

# %%
classifier5 = tree.DecisionTreeClassifier(criterion = 'entropy', min_samples_split=375)
classifier5.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=375)

# %%
# Making the Confusion Matrix for training and testing sets

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = classifier5.predict(X_train)
cm = confusion_matrix(y_train, y_pred)
print('confusion matrix on training data:\n',cm)
accuracy = classifier5.score(X_train, y_train)
print("Accuracy from Decision tree classifier on training data \n", accuracy)


y_pred = classifier5.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print('confusion matrix on testing data:\n',cm)
accuracy = classifier5.score(X_test, y_test)
print("accuracy from Decision tree classifier on testing data\n", accuracy)
# Out:
# confusion matrix on training data:
#  [[4946    0]
#  [ 168    0]]
# Accuracy from Decision tree classifier on training data
#  0.9671490027375831
# confusion matrix on testing data:
#  [[1653    0]
#  [  52    0]]
# accuracy from Decision tree classifier on testing data
#  0.9695014662756598

# %% [markdown]
# AUC and ROC

# %%
pred_prob1 = classifier1.predict_proba(X_test)
pred_prob2 = classifier2.predict_proba(X_test)
pred_prob3 = classifier3.predict_proba(X_test)
pred_prob4 = classifier4.predict_proba(X_test)
pred_prob5 = classifier5.predict_proba(X_test)

# %%
from sklearn.metrics import roc_curve
# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob1[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob2[:,1], pos_label=1)
fpr3, tpr3, thresh3 = roc_curve(y_test, pred_prob3[:,1], pos_label=1)
fpr4, tpr4, thresh4 = roc_curve(y_test, pred_prob5[:,1], pos_label=1)
fpr5, tpr5, thresh5 = roc_curve(y_test, pred_prob5[:,1], pos_label=1)

print(thresh1)
# roc curve for tpr = fpr
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)
# Out:
# [1.99997099e+00 9.99970994e-01 9.43727250e-01 9.08554789e-01
#  8.80129688e-01 8.61198089e-01 7.58616875e-01 6.60384333e-01
#  6.37739502e-01 5.94796559e-01 5.33907033e-01 5.32407450e-01
#  4.79877934e-01 4.76333148e-01 4.33503047e-01 4.11904959e-01
#  3.95718898e-01 3.81781566e-01 3.72394860e-01 3.50982604e-01
#  3.43117623e-01 3.39069919e-01 3.29282018e-01 3.20469938e-01
#  3.12413229e-01 3.05351729e-01 3.02098035e-01 2.97901265e-01
#  2.86600198e-01 2.32328192e-01 2.28439296e-01 1.91508504e-01
#  1.91217182e-01 1.74619476e-01 1.73851774e-01 1.71193071e-01
#  1.71012919e-01 1.63988666e-01 1.63808679e-01 9.56320048e-02
#  9.48455246e-02 8.50279411e-02 8.46868570e-02 8.31170428e-02
#  8.24202710e-02 6.48824150e-02 6.27914367e-02 6.13282040e-02
#  6.07476386e-02 6.01765269e-02 5.97331393e-02 5.69206687e-02
#  5.66757834e-02 4.58281732e-02 4.55792731e-02 4.36463689e-02
#  4.35765638e-02 3.70024827e-02 3.69031426e-02 3.19291927e-02
#  3.18823958e-02 3.14163645e-02 3.14122648e-02 2.93265202e-02
#  2.92195765e-02 2.64124349e-02 2.63845138e-02 2.38226908e-02
#  2.37136379e-02 2.08873736e-02 2.08268816e-02 1.45008721e-02
#  1.42785235e-02 1.38931174e-02 1.38915702e-02 8.19782249e-03
#  8.19621553e-03 1.60625501e-03 1.59804844e-03 8.28005787e-08
#  8.22305536e-08 4.39345554e-14 1.66921231e-16 2.21670157e-22]

# %%
from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, pred_prob1[:,1])
auc_score2 = roc_auc_score(y_test, pred_prob2[:,1])
auc_score3 = roc_auc_score(y_test, pred_prob3[:,1])
auc_score4 = roc_auc_score(y_test, pred_prob4[:,1])
auc_score5 = roc_auc_score(y_test, pred_prob5[:,1])
print(auc_score1, auc_score2, auc_score3,auc_score4,auc_score5)
# Out:
# 0.8916189678440132 0.9164281725533995 0.9139036251105216 0.8772162501745079 0.9093664200288519

# %%
plt.style.use('seaborn')
# plot roc curves
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='Logistic Regression')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='KNN')
plt.plot(fpr3, tpr3, linestyle='--',color='yellow', label='DecisionTree_1')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
# title
plt.title('ROC curve')
# x labe
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('ROC',dpi=500)
plt.show()
# Out:
# <ipython-input-46-353b5da13f27>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
